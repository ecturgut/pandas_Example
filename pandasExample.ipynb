# %%
import pandas as pd

# %%
players = pd.read_csv("fifa23.csv", index_col = "Name")

# %%
players.shape
# Out:
# (16456, 20)

# %%
players.head()
# Out:
#                  Ratings    Position           Version    PS  SKI  WF     WR  \
# Name
# Pelé                  98         CAM   Icon  Explosive     0    5   4  H \ M
# Ronaldo               96          ST  Icon  Controlled     0    5   5  M \ M
# Zinedine Zidane       96         CAM  Icon  Controlled     0    5   5  M \ M
# Pelé                  95  CF  CAM,ST   Icon  Explosive  4.2M    5   4  H \ M
# Ferenc Puskás         94          CF  Icon  Controlled     0    4   3  H \ M
#
#                  PAC  SHO  PAS  DRI  DEF  PHY                          Body  \
# Name
# Pelé              95   96   93   96   60   76   173cm | 5'8"  Unique (70kg)
# Ronaldo           97   95   81   95   45   76       183cm | 6'0"  R9 (78kg)
# Zinedine Zidane   85   92   96   95   75   86  185cm | 6'1"  Average (77kg)
# Pelé              96   93   90   95   56   75   173cm | 5'8"  Unique (69kg)
# Ferenc Puskás     91   96   91   92   46   76   172cm | 5'8"  Stocky (72kg)
#
# ...

# %%
players.loc["Ronaldinho"]
# Out:
#             Ratings    Position           Version     PS  SKI  WF     WR  PAC  \
# Name
# Ronaldinho       94          LW  Icon  Controlled      0    5   4  H \ L   92
# Ronaldinho       91  CAM  CF,LW  Icon  Controlled  2.67M    5   4  H \ L   91
# Ronaldinho       89     CAM  LW  Icon  Controlled  1.02M    5   4  M \ L   80
#
#             SHO  PAS  DRI  DEF  PHY                              Body  \
# Name
# Ronaldinho   90   91   95   37   81  180cm | 5'11"  Ronaldinho (78kg)
# Ronaldinho   86   88   92   36   79  180cm | 5'11"  Ronaldinho (76kg)
# Ronaldinho   85   88   90   38   77  180cm | 5'11"  Ronaldinho (79kg)
#
#             Popularity   BS   IGS          Club League Country
# Name
# Ronaldinho        1802  486  2328  FUT 22 ICONS  Icons  Brazil
# Ronaldinho        1865  472  2261  FUT 22 ICONS  Icons  Brazil
# Ronaldinho         925  458  2217  FUT 22 ICONS  Icons  Brazil
